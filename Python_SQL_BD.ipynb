# %% [markdown]
# <a href="https://colab.research.google.com/github/vickdurazzo/python_pandas/blob/main/Python_SQL_BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importa as bibliotecas**

# %%
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# **Especifica o nome do arquivo de dados e cria a conexão**

# %%
arquivo_bd = '/content/olist.db'

# %%
con = sql.connect(arquivo_bd)

# %% [markdown]
# **Define a query a ser usada**

# %%
query = "SELECT * FROM ORDERS;"

# %%
print(query)
# Out:
# SELECT * FROM ORDERS;

# %% [markdown]
# **Usando o pandas para criar um dataframe a partir da query**

# %%
df = pd.read_sql_query(query,con)

# %%
df.head(100)
# Out:
#                             order_id                       customer_id  \
# 0   e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1   53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2   47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3   949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4   ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ..                               ...                               ...
# 95  77e9941864fc840be8e4b1ba5347c0f7  3135962ee745ef39b85576df7ddbaa99
# 96  41bb5cee06dbf170878a9ef93ac7e7f5  1833a0540067becaf59368fe4cd4303a
# 97  6a0a8bfbbe700284feb0845d95e0867f  68451b39b1314302c08c65a29f1140fc
# 98  f7959f8385f34c4f645327465a1c9fc4  0bf19317b1830a69e55b40710576aa7a
# 99  23f553848a03aaab35bb3f9f87725125  c622b892a190735ef81c0087973fa16d
#
#    order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp order_approved_at  \
# count         99441                    99441             99441
# unique            8                    98875             90734
# top       delivered      2018-04-11 10:48:14
# freq          96478                        3               160
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         99441                         99441
# unique                        81019                         95665
# top
# freq                           1783                          2965
#
# ...

# %% [markdown]
# **Criando uma nova query**

# %%
query2 = "SELECT PAYMENT_TYPE,AVG(PAYMENT_VALUE) FROM ORDER_PAYMENTS GROUP BY PAYMENT_TYPE"

# %%
df2 = pd.read_sql_query(query2,con)

# %%
df2.head()
# Out:
#   payment_type  AVG(PAYMENT_VALUE)
# 0       boleto          145.034435
# 1  credit_card          163.319021
# 2   debit_card          142.570170
# 3  not_defined            0.000000
# 4      voucher           65.703354
